# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivaacharya138/Logistic_regression/blob/main/Logistic_Regression_Shiva_Acharya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1493           1183     1          0.5         1   3       1          48
# 1494            574     1          2.0         1   0       1          26
# 1495           1472     0          3.0         0   4       1          20
# 1496           1868     1          0.5         0   2       1          40
# 1497           1375     0          2.9         0   2       0          20
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.shape
# Out:
# (1498, 21)

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.replace('?', np.nan)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1493           1183     1          0.5         1   3       1          48
# 1494            574     1          2.0         1   0       1          26
# 1495           1472     0          3.0         0   4       1          20
# 1496           1868     1          0.5         0   2       1          40
# 1497           1375     0          2.9         0   2       0          20
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  1498 non-null   int64
#  1   blue           1498 non-null   int64
#  2   clock_speed    1498 non-null   float64
#  3   dual_sim       1498 non-null   int64
#  4   fc             1498 non-null   int64
#  5   four_g         1498 non-null   int64
#  6   int_memory     1498 non-null   int64
#  7   m_dep          1498 non-null   float64
#  8   mobile_wt      1498 non-null   int64
#  9   n_cores        1498 non-null   int64
#  10  pc             1498 non-null   int64
#  11  px_height      1498 non-null   int64
#  12  px_width       1498 non-null   int64
#  13  ram            1498 non-null   int64
#  14  sc_h           1498 non-null   int64
#  15  sc_w           1498 non-null   int64
#  16  talk_time      1498 non-null   int64
#  17  three_g        1498 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.select_dtypes('int').columns
# Out:
# Index(['battery_power', 'blue', 'dual_sim', 'fc', 'four_g', 'int_memory',
#        'mobile_wt', 'n_cores', 'pc', 'px_height', 'px_width', 'ram', 'sc_h',
#        'sc_w', 'talk_time', 'three_g', 'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.select_dtypes('float').columns
# Out:
# Index(['clock_speed', 'm_dep'], dtype='object')

# %%
df.select_dtypes('object').columns
# Out:
# Index([], dtype='object')

# %%
df.price_range.value_counts()
# Out:
# 3    379
# 0    375
# 2    373
# 1    371
# Name: price_range, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
X = df.drop(['price_range'], axis=1)
y = df['price_range']

# %%
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1493           1183     1          0.5         1   3       1          48
# 1494            574     1          2.0         1   0       1          26
# 1495           1472     0          3.0         0   4       1          20
# 1496           1868     1          0.5         0   2       1          40
# 1497           1375     0          2.9         0   2       0          20
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1493    0
# 1494    0
# 1495    0
# 1496    0
# 1497    3
# Name: price_range, Length: 1498, dtype: int64

# %%
LR.fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
df1 = pd.read_csv('test.csv')
df1.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            881     0          1.0         0   1       0          64    0.5
# 1           1742     1          0.5         1   5       1          43    0.9
# 2           1225     0          0.7         1   6       0          60    0.1
# 3           1970     1          0.5         1   0       1          15    1.0
# 4           1186     1          0.5         1   2       0          21    0.4
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        160        3  ...        115       636  2110    18     9          6
# 1        176        3  ...        356      1407  1921     9     2          3
# 2        107        2  ...         10      1567  2423    17    11          6
# 3        132        2  ...       1399      1684  1658    15     9         20
# 4        160        8  ...         68       584  2361    17     8          7
#
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  502 non-null    int64
#  1   blue           502 non-null    int64
#  2   clock_speed    502 non-null    float64
#  3   dual_sim       502 non-null    int64
#  4   fc             502 non-null    int64
#  5   four_g         502 non-null    int64
#  6   int_memory     502 non-null    int64
#  7   m_dep          502 non-null    float64
#  8   mobile_wt      502 non-null    int64
#  9   n_cores        502 non-null    int64
#  10  pc             502 non-null    int64
#  11  px_height      502 non-null    int64
#  12  px_width       502 non-null    int64
#  13  ram            502 non-null    int64
#  14  sc_h           502 non-null    int64
#  15  sc_w           502 non-null    int64
#  16  talk_time      502 non-null    int64
#  17  three_g        502 non-null    int64
# ...

# %%
df1.price_range.value_counts()
# Out:
# 1    129
# 2    127
# 0    125
# 3    121
# Name: price_range, dtype: int64

# %%
X_test = df1.drop(['price_range'], axis=1)
y_test = df1.price_range

# %%
y_pred = LR.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 2, 1, 2, 1, 3, 0, 2, 1, 2, 3, 3, 1, 3, 1, 1, 1, 3, 2, 2, 2,
#        3, 1, 2, 0, 1, 2, 2, 3, 1, 1, 0, 3, 3, 0, 2, 2, 2, 2, 2, 0, 1, 3,
#        3, 3, 2, 3, 3, 2, 3, 0, 3, 1, 1, 0, 1, 0, 3, 2, 1, 3, 1, 1, 2, 2,
#        0, 1, 0, 2, 3, 1, 0, 3, 2, 0, 3, 2, 0, 1, 1, 1, 0, 0, 0, 3, 0, 3,
#        0, 1, 1, 3, 3, 1, 1, 1, 2, 2, 3, 0, 3, 3, 1, 1, 3, 1, 0, 2, 3, 3,
#        1, 2, 2, 2, 2, 2, 3, 3, 3, 2, 3, 1, 3, 3, 2, 0, 0, 0, 1, 3, 2, 1,
#        0, 2, 2, 1, 0, 3, 1, 0, 1, 3, 1, 2, 3, 0, 1, 0, 1, 0, 2, 2, 0, 1,
#        1, 3, 0, 3, 1, 1, 2, 2, 2, 1, 1, 3, 1, 1, 3, 0, 1, 2, 3, 0, 1, 1,
#        3, 2, 2, 2, 3, 3, 1, 2, 1, 1, 3, 3, 3, 0, 3, 1, 2, 1, 3, 2, 1, 1,
#        2, 3, 0, 0, 0, 2, 2, 0, 2, 1, 3, 0, 2, 3, 0, 2, 1, 0, 3, 0, 2, 2,
#        2, 0, 3, 0, 2, 0, 2, 1, 2, 3, 0, 3, 0, 0, 1, 3, 3, 3, 1, 3, 2, 2,
#        3, 0, 0, 2, 1, 0, 1, 1, 2, 3, 1, 2, 3, 0, 3, 3, 2, 3, 0, 3, 1, 1,
#        1, 2, 3, 3, 1, 3, 3, 1, 3, 1, 3, 1, 3, 0, 3, 2, 3, 3, 0, 3, 3, 0,
# ...

# %%
Pred_df = pd.DataFrame(y_pred, columns=['Pred_values'])

# %%
Pred_df.to_csv('predictions.csv', index=False)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[95, 28,  2,  0],
#        [16, 70, 33, 10],
#        [ 0, 33, 59, 35],
#        [ 0,  0, 24, 97]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6394422310756972

# %%
from sklearn.metrics import classification_report
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.86      0.76      0.81       125\n           1       0.53      0.54      0.54       129\n           2       0.50      0.46      0.48       127\n           3       0.68      0.80      0.74       121\n\n    accuracy                           0.64       502\n   macro avg       0.64      0.64      0.64       502\nweighted avg       0.64      0.64      0.64       502\n'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.feature_names = df.drop(['price_range'],axis=1).columns
coef_df = pd.DataFrame({'coef': LR.coef_[0], 'feature': df.feature_names})

coef_df = coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index)

print(coef_df)
# Out:
#         coef        feature
# 8   0.045593      mobile_wt
# 6   0.015877     int_memory
# 14  0.008590           sc_h
# 16  0.005500      talk_time
# 10  0.004757             pc
# 13 -0.004469            ram
# 15  0.004215           sc_w
# 9   0.003360        n_cores
# 11 -0.002096      px_height
# 4   0.001656             fc
# 12  0.001441       px_width
# 2   0.001237    clock_speed
# 0  -0.000613  battery_power
# 18  0.000484   touch_screen
# 17  0.000417        three_g
# 5   0.000350         four_g
# 3   0.000324       dual_sim
# 1   0.000306           blue
# 19  0.000300           wifi
# 7   0.000230          m_dep
